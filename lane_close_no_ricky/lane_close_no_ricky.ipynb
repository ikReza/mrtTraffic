# %%
import pandas as pd

# %%
excel_file_path = "tripinfo.xlsx"
df = pd.read_excel(excel_file_path)
df.head()
# Out:
#                      Vehicle_ID  Depart  Arrival  Duration  Waiting Time  \
# 0  flow_east_to_east_rickshaw.0       1      128       127             0
# 1          flow_east_to_south.0       0      136       136             0
# 2  flow_east_to_east_rickshaw.2      16      141       125             0
# 3           flow_east_to_east.0       0      145       145             0
# 4  flow_east_to_east_rickshaw.1       8      146       138             0
#
#    Departure Delay          Vehicle
# 0              1.0  motorcycleDist2
# 1              0.0         carDist2
# 2              0.0  motorcycleDist2
# 3              0.0         cngDist2
# 4              0.0         cngDist2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6848 entries, 0 to 6847
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Vehicle_ID       6848 non-null   object
#  1   Depart           6848 non-null   int64
#  2   Arrival          6848 non-null   int64
#  3   Duration         6848 non-null   int64
#  4   Waiting Time     6848 non-null   int64
#  5   Departure Delay  6848 non-null   float64
#  6   Vehicle          6848 non-null   object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 374.6+ KB

# %%
df.describe()
# Out:
#             Depart      Arrival     Duration  Waiting Time  Departure Delay
# count  6848.000000  6848.000000  6848.000000   6848.000000      6848.000000
# mean   1650.820532  1894.447284   243.626752     31.800818         0.462395
# std     970.119993   987.336262   157.941949     75.780317         2.385049
# min       0.000000   128.000000   125.000000      0.000000         0.000000
# 25%     815.000000  1045.000000   175.000000      0.000000         0.000000
# 50%    1631.500000  1880.500000   199.000000     14.000000         0.070000
# 75%    2472.500000  2753.250000   244.000000     25.000000         0.650000
# max    3452.000000  3599.000000  1461.000000    615.000000        81.800000

# %%
def get_direction(vehicle_id):
    parts = vehicle_id.split("_")
    direction = parts[1]
    return direction

# %%
df["Ingress Point"] = df["Vehicle_ID"].apply(get_direction)
df.head()
# Out:
#                      Vehicle_ID  Depart  Arrival  Duration  Waiting Time  \
# 0  flow_east_to_east_rickshaw.0       1      128       127             0
# 1          flow_east_to_south.0       0      136       136             0
# 2  flow_east_to_east_rickshaw.2      16      141       125             0
# 3           flow_east_to_east.0       0      145       145             0
# 4  flow_east_to_east_rickshaw.1       8      146       138             0
#
#    Departure Delay          Vehicle Ingress Point
# 0              1.0  motorcycleDist2          east
# 1              0.0         carDist2          east
# 2              0.0  motorcycleDist2          east
# 3              0.0         cngDist2          east
# 4              0.0         cngDist2          east

# %%
directions = ["north", "south", "east", "west"]
results = {}

for direction in directions:
        # Filter the DataFrame for the current direction
        df_direction = df[df['Ingress Point'] == direction]

        # Calculate the number of vehicles
        num_vehicles = len(df_direction)

        # Calculate the metrics only if there are vehicles for the direction
        if num_vehicles > 0:
            # Calculate average travel time
            average_travel_time = df_direction['Duration'].mean()

            # Calculate average waiting time
            average_waiting_time = df_direction['Waiting Time'].mean()

            # Calculate average departure delay
            average_departure_delay = df_direction['Departure Delay'].mean()
        else:
            average_travel_time = 0
            average_waiting_time = 0
            average_departure_delay = 0

        # Store the results in the dictionary
        results[direction] = {
            'number_of_vehicles': num_vehicles,
            'average_travel_time': average_travel_time,
            'average_waiting_time': average_waiting_time,
            'average_departure_delay': average_departure_delay
        }

# %%
df_results = pd.DataFrame(results)
df_results["Overall Average"] = df_results.iloc[:, 1:].mean(axis=1)
df_results
# Out:
#                                north        south        east        west  \
# number_of_vehicles       2969.000000  2328.000000  938.000000  613.000000
# average_travel_time       224.658808   188.168385  469.892324  199.884176
# average_waiting_time       16.970360     7.636598  147.371002   18.556281
# average_departure_delay     0.405655     0.245696    1.144563    0.516330
#
#                          Overall Average
# number_of_vehicles           1293.000000
# average_travel_time           285.981628
# average_waiting_time           57.854627
# average_departure_delay         0.635529
