# %%
import pandas as pd

# %%
excel_file_path = "tripinfo.xlsx"
df = pd.read_excel(excel_file_path)
df.head()
# Out:
#               Vehicle_ID  Depart  Arrival  Duration  Waiting Time  \
# 0    flow_east_to_east.0       0      125       125             0
# 1   flow_west_to_north.0       0      143       143             0
# 2   flow_west_to_north.2      12      147       135             0
# 3  flow_south_to_north.4       8      149       141             5
# 4    flow_east_to_east.1      15      149       134             0
#
#    Departure Delay          Vehicle
# 0             0.00         carDist2
# 1             0.00  motorcycleDist3
# 2             0.92  motorcycleDist3
# 3             0.38  motorcycleDist1
# 4             0.60    microbusDist2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6081 entries, 0 to 6080
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Vehicle_ID       6081 non-null   object
#  1   Depart           6081 non-null   int64
#  2   Arrival          6081 non-null   int64
#  3   Duration         6081 non-null   int64
#  4   Waiting Time     6081 non-null   int64
#  5   Departure Delay  6081 non-null   float64
#  6   Vehicle          6081 non-null   object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 332.7+ KB

# %%
df.describe()
# Out:
#             Depart      Arrival     Duration  Waiting Time  Departure Delay
# count  6081.000000  6081.000000  6081.000000   6081.000000      6081.000000
# mean   1443.023187  1868.779642   425.756455     77.041276        37.791181
# std     893.142264   991.475419   270.386783     64.016431       120.381935
# min       0.000000   125.000000   121.000000      0.000000         0.000000
# 25%     676.000000  1010.000000   231.000000     33.000000         0.240000
# 50%    1364.000000  1853.000000   334.000000     60.000000         0.590000
# 75%    2184.000000  2744.000000   561.000000    106.000000         0.940000
# max    3406.000000  3599.000000  1550.000000    365.000000       734.350000

# %%
def get_direction(vehicle_id):
    parts = vehicle_id.split("_")
    direction = parts[1]
    return direction

# %%
df["Ingress Point"] = df["Vehicle_ID"].apply(get_direction)
df.head()
# Out:
#               Vehicle_ID  Depart  Arrival  Duration  Waiting Time  \
# 0    flow_east_to_east.0       0      125       125             0
# 1   flow_west_to_north.0       0      143       143             0
# 2   flow_west_to_north.2      12      147       135             0
# 3  flow_south_to_north.4       8      149       141             5
# 4    flow_east_to_east.1      15      149       134             0
#
#    Departure Delay          Vehicle Ingress Point
# 0             0.00         carDist2          east
# 1             0.00  motorcycleDist3          west
# 2             0.92  motorcycleDist3          west
# 3             0.38  motorcycleDist1         south
# 4             0.60    microbusDist2          east

# %%
directions = ["north", "south", "east", "west"]
results = {}

for direction in directions:
        # Filter the DataFrame for the current direction
        df_direction = df[df['Ingress Point'] == direction]

        # Calculate the number of vehicles
        num_vehicles = len(df_direction)

        # Calculate the metrics only if there are vehicles for the direction
        if num_vehicles > 0:
            # Calculate average travel time
            average_travel_time = df_direction['Duration'].mean()

            # Calculate average waiting time
            average_waiting_time = df_direction['Waiting Time'].mean()

            # Calculate average departure delay
            average_departure_delay = df_direction['Departure Delay'].mean()
        else:
            average_travel_time = 0
            average_waiting_time = 0
            average_departure_delay = 0

        # Store the results in the dictionary
        results[direction] = {
            'number_of_vehicles': num_vehicles,
            'average_travel_time': average_travel_time,
            'average_waiting_time': average_waiting_time,
            'average_departure_delay': average_departure_delay
        }

# %%
df_results = pd.DataFrame(results)
df_results["Overall Average"] = df_results.iloc[:, 1:].mean(axis=1)
df_results
# Out:
#                                north        south         east        west  \
# number_of_vehicles       1943.000000  2141.000000  1166.000000  615.000000
# average_travel_time       641.503860   354.980850   290.234991  200.873171
# average_waiting_time      107.919712    63.512844    76.848199   18.956098
# average_departure_delay   111.522064     0.615979     0.522950    0.514195
#
#                          Overall Average
# number_of_vehicles           1307.333333
# average_travel_time           282.029671
# average_waiting_time           53.105714
# average_departure_delay         0.551041
